# %%
import pandas as pd
import numpy as np

# %%
# read in the csv
overdoses = pd.read_csv("merged_data.csv")
overdoses.head(10)
# Out:
#   Notes              County  County Code  Year  Year Code  \
# 0   NaN  Autauga County, AL       1001.0  2003     2003.0
# 1   NaN  Baldwin County, AL       1003.0  2003     2003.0
# 2   NaN  Baldwin County, AL       1003.0  2003     2003.0
# 3   NaN  Baldwin County, AL       1003.0  2003     2003.0
# 4   NaN  Barbour County, AL       1005.0  2003     2003.0
# 5   NaN     Bibb County, AL       1007.0  2003     2003.0
# 6   NaN   Blount County, AL       1009.0  2003     2003.0
# 7   NaN  Bullock County, AL       1011.0  2003     2003.0
# 8   NaN   Butler County, AL       1013.0  2003     2003.0
# 9   NaN  Calhoun County, AL       1015.0  2003     2003.0
#
#                           Drug/Alcohol Induced Cause  \
# 0          All other non-drug and non-alcohol causes
# 1  Drug poisonings (overdose) Unintentional (X40-...
# 2                   All other alcohol-induced causes
# 3          All other non-drug and non-alcohol causes
# 4          All other non-drug and non-alcohol causes
# 5          All other non-drug and non-alcohol causes
# 6          All other non-drug and non-alcohol causes
# 7          All other non-drug and non-alcohol causes
# 8          All other non-drug and non-alcohol causes
# 9          All other non-drug and non-alcohol causes
#
#   Drug/Alcohol Induced Cause Code  Deaths
# 0                              O9   397.0
# 1                              D1    10.0
# 2                              A9    14.0
# 3                              O9  1479.0
# 4                              O9   287.0
# 5                              O9   226.0
# 6                              O9   552.0
# 7                              O9   121.0
# 8                              O9   308.0
# 9                              O9  1286.0

# %%
overdoses.shape
# Out:
# (57436, 8)

# %%
overdoses["County"].head(10)
# Out:
# 0    Autauga County, AL
# 1    Baldwin County, AL
# 2    Baldwin County, AL
# 3    Baldwin County, AL
# 4    Barbour County, AL
# 5       Bibb County, AL
# 6     Blount County, AL
# 7    Bullock County, AL
# 8     Butler County, AL
# 9    Calhoun County, AL
# Name: County, dtype: object

# %%
# Here we subset by the policy states. We will need to add the control states.
selected_states = ["FL", "TX", "WA"]

filtered_df = overdoses[overdoses["County"].notna()]
filtered_df = filtered_df[filtered_df["County"].str.endswith(tuple(selected_states))]

filtered_df.head(10)
# Out:
#     Notes               County  County Code  Year  Year Code  \
# 500   NaN   Alachua County, FL      12001.0  2003     2003.0
# 501   NaN   Alachua County, FL      12001.0  2003     2003.0
# 502   NaN   Alachua County, FL      12001.0  2003     2003.0
# 503   NaN     Baker County, FL      12003.0  2003     2003.0
# 504   NaN       Bay County, FL      12005.0  2003     2003.0
# 505   NaN       Bay County, FL      12005.0  2003     2003.0
# 506   NaN       Bay County, FL      12005.0  2003     2003.0
# 507   NaN  Bradford County, FL      12007.0  2003     2003.0
# 508   NaN   Brevard County, FL      12009.0  2003     2003.0
# 509   NaN   Brevard County, FL      12009.0  2003     2003.0
#
#                             Drug/Alcohol Induced Cause  \
# 500  Drug poisonings (overdose) Unintentional (X40-...
# 501                   All other alcohol-induced causes
# 502          All other non-drug and non-alcohol causes
# 503          All other non-drug and non-alcohol causes
# 504  Drug poisonings (overdose) Unintentional (X40-...
# 505                   All other alcohol-induced causes
# 506          All other non-drug and non-alcohol causes
# 507          All other non-drug and non-alcohol causes
# 508  Drug poisonings (overdose) Unintentional (X40-...
# 509       Drug poisonings (overdose) Suicide (X60-X64)
#
#     Drug/Alcohol Induced Cause Code  Deaths
# 500                              D1    11.0
# 501                              A9    11.0
# 502                              O9  1568.0
# 503                              O9   200.0
# 504                              D1    21.0
# 505                              A9    16.0
# 506                              O9  1405.0
# 507                              O9   243.0
# 508                              D1    83.0
# 509                              D2    14.0

# %%
# Checking that it was reduced
filtered_df.shape
# Out:
# (7216, 8)

# %%
# Put all the different categories into 1 series for further filtering
causes_of_death = filtered_df["Drug/Alcohol Induced Cause"].unique()
causes_of_death
# Out:
# array(['Drug poisonings (overdose) Unintentional (X40-X44)',
#        'All other alcohol-induced causes',
#        'All other non-drug and non-alcohol causes',
#        'Drug poisonings (overdose) Suicide (X60-X64)',
#        'All other drug-induced causes',
#        'Drug poisonings (overdose) Undetermined (Y10-Y14)',
#        'Alcohol poisonings (overdose) (X45, X65, Y15)'], dtype=object)

# %%
# We will add all 7 options for deaths into each county to begin accounting for missing deaths
all_combinations = pd.DataFrame(
    [
        (county, year, cause)
        for county in filtered_df["County"].unique()
        for year in filtered_df["Year"].unique()
        for cause in causes_of_death
    ],
    columns=["County", "Year", "Drug/Alcohol Induced Cause"],
)

# merge the datasets
merged_data = pd.merge(
    all_combinations,
    filtered_df,
    how="left",
    on=["County", "Year", "Drug/Alcohol Induced Cause"],
)

merged_data = merged_data.fillna(np.nan)

merged_data.head(10)
# Out:
#                County  Year  \
# 0  Alachua County, FL  2003
# 1  Alachua County, FL  2003
# 2  Alachua County, FL  2003
# 3  Alachua County, FL  2003
# 4  Alachua County, FL  2003
# 5  Alachua County, FL  2003
# 6  Alachua County, FL  2003
# 7  Alachua County, FL  2004
# 8  Alachua County, FL  2004
# 9  Alachua County, FL  2004
#
#                           Drug/Alcohol Induced Cause  Notes  County Code  \
# 0  Drug poisonings (overdose) Unintentional (X40-...    NaN      12001.0
# 1                   All other alcohol-induced causes    NaN      12001.0
# 2          All other non-drug and non-alcohol causes    NaN      12001.0
# 3       Drug poisonings (overdose) Suicide (X60-X64)    NaN          NaN
# 4                      All other drug-induced causes    NaN          NaN
# 5  Drug poisonings (overdose) Undetermined (Y10-Y14)    NaN          NaN
# 6      Alcohol poisonings (overdose) (X45, X65, Y15)    NaN          NaN
# 7  Drug poisonings (overdose) Unintentional (X40-...    NaN          NaN
# 8                   All other alcohol-induced causes    NaN      12001.0
# 9          All other non-drug and non-alcohol causes    NaN      12001.0
#
#    Year Code Drug/Alcohol Induced Cause Code  Deaths
# 0     2003.0                              D1    11.0
# 1     2003.0                              A9    11.0
# 2     2003.0                              O9  1568.0
# 3        NaN                             NaN     NaN
# 4        NaN                             NaN     NaN
# 5        NaN                             NaN     NaN
# 6        NaN                             NaN     NaN
# 7        NaN                             NaN     NaN
# 8     2004.0                              A9    19.0
# 9     2004.0                              O9  1511.0

# %%
# Only filled in data
filtered_df[filtered_df["County"] == "Alachua County, FL"].shape
# Out:
# (35, 8)

# %%
# 13 years * 7 causes of deaths  =  91 options for each county. This has been properly added.
merged_data[merged_data["County"] == "Alachua County, FL"].shape
# Out:
# (91, 8)

# %%
# Let's subset to just drug overdose categories.
# Still need to check drug/alcohol induced codes to hopefully filter to only opioids.
only_overdoses = [
    "Drug poisonings (overdose) Undetermined (Y10-Y14)",
    "Drug poisonings (overdose) Suicide (X60-X64)",
    "Drug poisonings (overdose) Unintentional (X40-X44)",
]

final_temp_df = merged_data[
    merged_data["Drug/Alcohol Induced Cause"].isin(only_overdoses)
]
final_temp_df.head(39)
# Out:
#                 County  Year  \
# 0   Alachua County, FL  2003
# 3   Alachua County, FL  2003
# 5   Alachua County, FL  2003
# 7   Alachua County, FL  2004
# 10  Alachua County, FL  2004
# 12  Alachua County, FL  2004
# 14  Alachua County, FL  2005
# 17  Alachua County, FL  2005
# 19  Alachua County, FL  2005
# 21  Alachua County, FL  2006
# 24  Alachua County, FL  2006
# 26  Alachua County, FL  2006
# 28  Alachua County, FL  2007
# 31  Alachua County, FL  2007
# 33  Alachua County, FL  2007
# 35  Alachua County, FL  2008
# 38  Alachua County, FL  2008
# 40  Alachua County, FL  2008
# 42  Alachua County, FL  2009
# 45  Alachua County, FL  2009
# 47  Alachua County, FL  2009
# 49  Alachua County, FL  2010
# 52  Alachua County, FL  2010
# 54  Alachua County, FL  2010
# 56  Alachua County, FL  2011
# 59  Alachua County, FL  2011
# 61  Alachua County, FL  2011
# 63  Alachua County, FL  2012
# 66  Alachua County, FL  2012
# 68  Alachua County, FL  2012
# 70  Alachua County, FL  2013
# 73  Alachua County, FL  2013
# 75  Alachua County, FL  2013
# 77  Alachua County, FL  2014
# 80  Alachua County, FL  2014
# 82  Alachua County, FL  2014
# 84  Alachua County, FL  2015
# 87  Alachua County, FL  2015
# 89  Alachua County, FL  2015
#
#                            Drug/Alcohol Induced Cause  Notes  County Code  \
# 0   Drug poisonings (overdose) Unintentional (X40-...    NaN      12001.0
# 3        Drug poisonings (overdose) Suicide (X60-X64)    NaN          NaN
# 5   Drug poisonings (overdose) Undetermined (Y10-Y14)    NaN          NaN
# 7   Drug poisonings (overdose) Unintentional (X40-...    NaN          NaN
# 10       Drug poisonings (overdose) Suicide (X60-X64)    NaN          NaN
# 12  Drug poisonings (overdose) Undetermined (Y10-Y14)    NaN          NaN
# 14  Drug poisonings (overdose) Unintentional (X40-...    NaN          NaN
# 17       Drug poisonings (overdose) Suicide (X60-X64)    NaN          NaN
# 19  Drug poisonings (overdose) Undetermined (Y10-Y14)    NaN          NaN
# 21  Drug poisonings (overdose) Unintentional (X40-...    NaN          NaN
# 24       Drug poisonings (overdose) Suicide (X60-X64)    NaN          NaN
# 26  Drug poisonings (overdose) Undetermined (Y10-Y14)    NaN          NaN
# 28  Drug poisonings (overdose) Unintentional (X40-...    NaN      12001.0
# 31       Drug poisonings (overdose) Suicide (X60-X64)    NaN          NaN
# 33  Drug poisonings (overdose) Undetermined (Y10-Y14)    NaN          NaN
# 35  Drug poisonings (overdose) Unintentional (X40-...    NaN          NaN
# 38       Drug poisonings (overdose) Suicide (X60-X64)    NaN          NaN
# 40  Drug poisonings (overdose) Undetermined (Y10-Y14)    NaN          NaN
# 42  Drug poisonings (overdose) Unintentional (X40-...    NaN      12001.0
# 45       Drug poisonings (overdose) Suicide (X60-X64)    NaN          NaN
# 47  Drug poisonings (overdose) Undetermined (Y10-Y14)    NaN          NaN
# 49  Drug poisonings (overdose) Unintentional (X40-...    NaN      12001.0
# 52       Drug poisonings (overdose) Suicide (X60-X64)    NaN          NaN
# 54  Drug poisonings (overdose) Undetermined (Y10-Y14)    NaN          NaN
# 56  Drug poisonings (overdose) Unintentional (X40-...    NaN      12001.0
# 59       Drug poisonings (overdose) Suicide (X60-X64)    NaN          NaN
# 61  Drug poisonings (overdose) Undetermined (Y10-Y14)    NaN          NaN
# 63  Drug poisonings (overdose) Unintentional (X40-...    NaN      12001.0
# 66       Drug poisonings (overdose) Suicide (X60-X64)    NaN          NaN
# 68  Drug poisonings (overdose) Undetermined (Y10-Y14)    NaN          NaN
# 70  Drug poisonings (overdose) Unintentional (X40-...    NaN      12001.0
# 73       Drug poisonings (overdose) Suicide (X60-X64)    NaN          NaN
# 75  Drug poisonings (overdose) Undetermined (Y10-Y14)    NaN          NaN
# 77  Drug poisonings (overdose) Unintentional (X40-...    NaN      12001.0
# 80       Drug poisonings (overdose) Suicide (X60-X64)    NaN          NaN
# 82  Drug poisonings (overdose) Undetermined (Y10-Y14)    NaN          NaN
# 84  Drug poisonings (overdose) Unintentional (X40-...    NaN      12001.0
# 87       Drug poisonings (overdose) Suicide (X60-X64)    NaN          NaN
# 89  Drug poisonings (overdose) Undetermined (Y10-Y14)    NaN          NaN
#
#     Year Code Drug/Alcohol Induced Cause Code Deaths
# 0      2003.0                              D1   11.0
# 3         NaN                             NaN    NaN
# 5         NaN                             NaN    NaN
# 7         NaN                             NaN    NaN
# 10        NaN                             NaN    NaN
# 12        NaN                             NaN    NaN
# 14        NaN                             NaN    NaN
# 17        NaN                             NaN    NaN
# 19        NaN                             NaN    NaN
# 21        NaN                             NaN    NaN
# 24        NaN                             NaN    NaN
# 26        NaN                             NaN    NaN
# 28     2007.0                              D1   17.0
# 31        NaN                             NaN    NaN
# 33        NaN                             NaN    NaN
# 35        NaN                             NaN    NaN
# 38        NaN                             NaN    NaN
# 40        NaN                             NaN    NaN
# 42     2009.0                              D1   15.0
# 45        NaN                             NaN    NaN
# 47        NaN                             NaN    NaN
# 49     2010.0                              D1   15.0
# 52        NaN                             NaN    NaN
# 54        NaN                             NaN    NaN
# 56     2011.0                              D1   14.0
# 59        NaN                             NaN    NaN
# 61        NaN                             NaN    NaN
# 63     2012.0                              D1   14.0
# 66        NaN                             NaN    NaN
# 68        NaN                             NaN    NaN
# 70     2013.0                              D1   12.0
# 73        NaN                             NaN    NaN
# 75        NaN                             NaN    NaN
# 77     2014.0                              D1   19.0
# 80        NaN                             NaN    NaN
# 82        NaN                             NaN    NaN
# 84     2015.0                              D1     23
# 87        NaN                             NaN    NaN
# 89        NaN                             NaN    NaN

# %% [markdown]
# ### To-Do & Problems

# %% [markdown]
# 1. We need to figure out a method to fill in all the NaNs with accurate counts of deaths for these other categories.
#
# 2. If we find total deaths for counties, it seems like there are still a lot of categories that are unnaccounted for so it will be hard to divide these between different categories.
#
# 3. Also need to add the control states.
